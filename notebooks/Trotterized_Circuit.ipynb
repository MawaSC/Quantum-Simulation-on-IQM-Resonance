# %% [markdown]
# ## IQM Resonance Example Notebook
# In order to get started, make sure you have the appropriate packages installed. As prerequisite, you need to have **Python 3.11** or above and pip installed on your system.
#
# You have chosen IQM Sirius as your quantum computer. The following code snippet also shows how to create an IQM client and connect to this specific device.
#
# Run the cell and enter your IQM Resonance API token when prompted. You can find your API token in your IQM Resonance UI account drawer.
# In order to install the packages and init the backend to work with IQM hardware in QRISP, run the following cell:

# %%
import sys
import subprocess

# --- Check Python version ---
major, minor = sys.version_info[:2]

if not (major == 3 and minor == 12):
    print(f"❌ Python {major}.{minor} detected.")
    print("Please change the Colab runtime to **Python 3.12**:")
    print("Runtime → Change runtime type → Runtime version → 2025.10")
    raise SystemExit

print(f"✅ Python {major}.{minor} detected (OK).")

# --- Check pip version ---
pip_version_output = subprocess.check_output(["pip", "--version"]).decode()
pip_version = pip_version_output.split()[1]  # e.g. "25.0"

print(f"Detected pip version: {pip_version}")

if not pip_version.startswith("25"):
    print("❌ pip version is not 25.x. Installing pip 25...")
    # !pip install --upgrade pip==25.*
    print("✅ pip 25 installed.")
    print("Please RESTART the runtime now (Runtime → Restart session).")
else:
    print("✅ pip 25.x is already installed.")
# Out:
# ✅ Python 3.12 detected (OK).
# Detected pip version: 25.3
# ✅ pip 25.x is already installed.

# %%
# !pip install qrisp
from qrisp import *
from matplotlib import pyplot as plt
# !pip install pylatexenc
from qiskit.visualization import circuit_drawer

# This example creates a GHZ state, replace it with your own code
qv = QuantumVariable(3)
h(qv[0])
cx(qv[0], qv[1])
cx(qv[0], qv[2])

result = qv.get_measurement()
# Print and plot the result
print(qv)

#plt.bar(result.keys(), result.values())
#plt.xlabel('Measurement outcomes')
#plt.ylabel('Probability')
#plt.show()
# Out:
# Requirement already satisfied: qrisp in /usr/local/lib/python3.12/dist-packages (0.9.6)
# Requirement already satisfied: numpy<2.5,>=2.0 in /usr/local/lib/python3.12/dist-packages (from qrisp) (2.0.2)
# Requirement already satisfied: sympy<=1.13 in /usr/local/lib/python3.12/dist-packages (from qrisp) (1.13.0)
# Requirement already satisfied: qiskit>=0.44.0 in /usr/local/lib/python3.12/dist-packages (from qrisp) (2.5.1)
# Requirement already satisfied: matplotlib>=3.5.1 in /usr/local/lib/python3.12/dist-packages (from qrisp) (3.10.0)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from qrisp) (1.16.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from qrisp) (0.60.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from qrisp) (3.6.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from qrisp) (4.67.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from qrisp) (0.3.8)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from qrisp) (5.9.5)
# Requirement already satisfied: jax==0.7.1 in /usr/local/lib/python3.12/dist-packages (from qrisp) (0.7.1)
# Requirement already satisfied: jaxlib==0.7.1 in /usr/local/lib/python3.12/dist-packages (from qrisp) (0.7.1)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax==0.7.1->qrisp) (0.5.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax==0.7.1->qrisp) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy<=1.13->qrisp) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.1->qrisp) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.44.0->qrisp) (0.18.1)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.44.0->qrisp) (5.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.44.0->qrisp) (4.16.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->qrisp) (0.43.0)
# Requirement already satisfied: pylatexenc in /usr/local/lib/python3.12/dist-packages (2.11)
# {'000': 0.5, '111': 0.5}

# %% [markdown]
# You have now successfully created a GHZ state on three qubits!.
#
# A GHZ state is named after Daniel Greenberger, Michael Horne, and Anton Zeilinger, who first described this type of entangled quantum state. It is a specific type of multi-qubit entangled state with two possible measurement outcomes: all qubits being in the state 0 or all qubits being in the state 1. The GHZ state is represented mathematically as:
# $$|GHZ_3⟩ = \frac{|000⟩ + |111⟩}{\sqrt{2}}$$
#
# This state is significant in quantum information theory and quantum computing because it exhibits strong correlations between the qubits, which cannot be explained by classical physics (in particular, it contradicts local hidden variable theories).
#
# You have successfully ran a quantum circuit. Please view the results in the IQM Resonance dashboard for further insights.
#
# Go to the [IQM Resonance](https://resonance.iqm.tech).

# %%
from qrisp import *
from numpy import *
from matplotlib import pyplot as plt

def f_swap(q0, q1):
    cz(q0, q1)
    swap(q0, q1)

def rxx(theta, q0, q1):
    h(q0)
    h(q1)
    rzz(theta, q0, q1)
    h(q0)
    h(q1)

def ryy(theta, q0, q1):
    rx(np.pi/2, q0)
    rx(np.pi/2, q1)
    rzz(theta, q0, q1)
    rx(-np.pi/2, q0)
    rx(-np.pi/2, q1)

def rxxyy(t, dt, q0, q1):
    theta = t * dt
    rxx(theta, q0, q1)
    ryy(theta, q0, q1)

total_time = 9.0
dt = 0.15
steps = 1 #int(total_time/dt)

def even_x_flip(qv):
  # State preparation (even-index X flips)
  for i in range(0, len(qv), 2):
      x(qv[i])
  return qv

def pair_interleaved_ordering(qv):
  # State preparation (i % 4)
  for i in range(len(qv)):
        if i % 4 == 0 or i % 4 == 3:
            x(qv[i])
  return qv

def Trotterized_Circuit(opt, num, mu, t, U, dt):
  # Create the quantum variable
  qv = QuantumVariable(num)

  if opt == 1:
    pair_interleaved_ordering(qv)
  else:
    even_x_flip(qv)

  for s in range(steps):
        apply_trotter_layer(qv, mu, t, U, dt)
  return qv


def apply_trotter_layer(qv, mu, t, U, dt):
  # Forward Order ---------------------------------
  # Onsite + chemical potential (purple)
  for i in range(len(qv)):
      rz(mu * dt, qv[i])
  # Even Hopping (blue)
  for i in range(0, len(qv), 2):
      rxxyy(t, dt, qv[i], qv[i+1])
  # Odd Hopping (blue)
  for i in range(1, len(qv) - 2, 2):
      rxxyy(t, dt, qv[i], qv[i+1])
  # Onsite interactions (yellow)
  for i in range(0, len(qv) - 1, 2):
      rzz(U * dt, qv[i], qv[i+1])
  # Fermionic swap (green)
  for i in range(0, len(qv) - 1, 2):
      f_swap(qv[i], qv[i+1])
  # Odd Hopping (blue)
  for i in range(1, len(qv) - 2, 2):
      rxxyy(t, dt, qv[i], qv[i+1])
  # Even Hopping (blue)
  for i in range(0, len(qv), 2):
      rxxyy(t, dt, qv[i], qv[i+1])
  # Onsite + chemical potential (purple)
  for i in range(len(qv)):
      rz(mu * dt, qv[i])

  # Reverse Order ---------------------------------
  # Onsite + chemical potential (purple)
  for i in range(len(qv)):
      rz(mu * dt, qv[i])
  # Even Hopping (blue)
  for i in range(0, len(qv), 2):
      rxxyy(t, dt, qv[i], qv[i+1])
  # Odd Hopping (blue)
  for i in range(1, len(qv) - 2, 2):
      rxxyy(t, dt, qv[i], qv[i+1])
  # Fermionic swap (green)
  for i in range(0, len(qv) - 1, 2):
      f_swap(qv[i], qv[i+1])
  # Onsite interactions (yellow)
  for i in range(0, len(qv) - 1, 2):
      rzz(U * dt, qv[i], qv[i+1])
  # Odd Hopping (blue)
  for i in range(1, len(qv) - 2, 2):
      rxxyy(t, dt, qv[i], qv[i+1])
  # Even Hopping (blue)
  for i in range(0, len(qv), 2):
      rxxyy(t, dt, qv[i], qv[i+1])
  # Onsite + chemical potential (purple)
  for i in range(len(qv)):
      rz(mu * dt, qv[i])
  return qv


qc = Trotterized_Circuit(opt=1, num=8,
    mu=0.0,
    t=1.0,
    U=10.0,
    dt = 0.15)
print(qc.qs)
print(qc)
# Out:
# QuantumCircuit:
# ---------------
#         ┌───┐  ┌───────┐┌───┐           ┌───┐┌─────────┐           ┌──────────┐»
# qv.0: ──┤ X ├──┤ Rz(0) ├┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├»
#       ┌─┴───┴─┐└─┬───┬─┘└───┘ │ZZ(0.15) ├───┤├─────────┤ │ZZ(0.15) ├──────────┤»
# qv.1: ┤ Rz(0) ├──┤ H ├────────■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├»
#       ├───────┤  ├───┤                  ├───┤├─────────┤           ├──────────┤»
# qv.2: ┤ Rz(0) ├──┤ H ├────────■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├»
#       └─┬───┬─┘┌─┴───┴─┐┌───┐ │ZZ(0.15) ├───┤├─────────┤ │ZZ(0.15) ├──────────┤»
# qv.3: ──┤ X ├──┤ Rz(0) ├┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├»
#         ├───┤  ├───────┤├───┤           ├───┤├─────────┤           ├──────────┤»
# qv.4: ──┤ X ├──┤ Rz(0) ├┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├»
#       ┌─┴───┴─┐└─┬───┬─┘└───┘ │ZZ(0.15) ├───┤├─────────┤ │ZZ(0.15) ├──────────┤»
# qv.5: ┤ Rz(0) ├──┤ H ├────────■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├»
#       ├───────┤  ├───┤                  ├───┤├─────────┤           ├──────────┤»
# qv.6: ┤ Rz(0) ├──┤ H ├────────■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├»
#       └─┬───┬─┘┌─┴───┴─┐┌───┐ │ZZ(0.15) ├───┤├─────────┤ │ZZ(0.15) ├──────────┤»
# qv.7: ──┤ X ├──┤ Rz(0) ├┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├»
#         └───┘  └───────┘└───┘           └───┘└─────────┘           └──────────┘»
# «                                                                             »
# «qv.0: ────────────────────────────────────────────────────────■─────────■──X─»
# «      ┌───┐           ┌───┐┌─────────┐           ┌──────────┐ │ZZ(1.5)  │  │ »
# «qv.1: ┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├─■─────────■──X─»
# «      ├───┤ │ZZ(0.15) ├───┤├─────────┤ │ZZ(0.15) ├──────────┤                »
# «qv.2: ┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├─■─────────■──X─»
# «      ├───┤           ├───┤├─────────┤           ├──────────┤ │ZZ(1.5)  │  │ »
# «qv.3: ┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├─■─────────■──X─»
# «      ├───┤ │ZZ(0.15) ├───┤├─────────┤ │ZZ(0.15) ├──────────┤                »
# «qv.4: ┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├─■─────────■──X─»
# «      ├───┤           ├───┤├─────────┤           ├──────────┤ │ZZ(1.5)  │  │ »
# «qv.5: ┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├─■─────────■──X─»
# «      ├───┤ │ZZ(0.15) ├───┤├─────────┤ │ZZ(0.15) ├──────────┤                »
# «qv.6: ┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├─■─────────■──X─»
# «      └───┘           └───┘└─────────┘           └──────────┘ │ZZ(1.5)  │  │ »
# «qv.7: ────────────────────────────────────────────────────────■─────────■──X─»
# «                                                                             »
# «      ┌───┐                                                                  »
# «qv.0: ┤ H ├────────────────────────────────────────────────────────■─────────»
# «      ├───┤           ┌───┐┌─────────┐           ┌──────────┐┌───┐ │ZZ(0.15) »
# «qv.1: ┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────»
# «      ├───┤ │ZZ(0.15) ├───┤├─────────┤ │ZZ(0.15) ├──────────┤├───┤           »
# «qv.2: ┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────»
# «      ├───┤           ├───┤├─────────┤           ├──────────┤├───┤ │ZZ(0.15) »
# «qv.3: ┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────»
# «      ├───┤ │ZZ(0.15) ├───┤├─────────┤ │ZZ(0.15) ├──────────┤├───┤           »
# «qv.4: ┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────»
# «      ├───┤           ├───┤├─────────┤           ├──────────┤├───┤ │ZZ(0.15) »
# «qv.5: ┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────»
# «      ├───┤ │ZZ(0.15) ├───┤├─────────┤ │ZZ(0.15) ├──────────┤├───┤           »
# «qv.6: ┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────»
# «      ├───┤           └───┘└─────────┘           └──────────┘└───┘ │ZZ(0.15) »
# «qv.7: ┤ H ├────────────────────────────────────────────────────────■─────────»
# «      └───┘                                                                  »
# «      ┌───┐┌─────────┐           ┌──────────┐┌───────┐┌───────┐┌───┐»
# «qv.0: ┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ Rz(0) ├┤ Rz(0) ├┤ H ├»
# «      ├───┤├─────────┤ │ZZ(0.15) ├──────────┤├───────┤├───────┤├───┤»
# «qv.1: ┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ Rz(0) ├┤ Rz(0) ├┤ H ├»
# «      ├───┤├─────────┤           ├──────────┤├───────┤├───────┤├───┤»
# «qv.2: ┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ Rz(0) ├┤ Rz(0) ├┤ H ├»
# «      ├───┤├─────────┤ │ZZ(0.15) ├──────────┤├───────┤├───────┤├───┤»
# «qv.3: ┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ Rz(0) ├┤ Rz(0) ├┤ H ├»
# «      ├───┤├─────────┤           ├──────────┤├───────┤├───────┤├───┤»
# «qv.4: ┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ Rz(0) ├┤ Rz(0) ├┤ H ├»
# «      ├───┤├─────────┤ │ZZ(0.15) ├──────────┤├───────┤├───────┤├───┤»
# «qv.5: ┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ Rz(0) ├┤ Rz(0) ├┤ H ├»
# «      ├───┤├─────────┤           ├──────────┤├───────┤├───────┤├───┤»
# «qv.6: ┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ Rz(0) ├┤ Rz(0) ├┤ H ├»
# «      ├───┤├─────────┤ │ZZ(0.15) ├──────────┤├───────┤├───────┤├───┤»
# «qv.7: ┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ Rz(0) ├┤ Rz(0) ├┤ H ├»
# «      └───┘└─────────┘           └──────────┘└───────┘└───────┘└───┘»
# «                 ┌───┐┌─────────┐           ┌──────────┐                     »
# «qv.0: ─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├─────────────────────»
# «       │ZZ(0.15) ├───┤├─────────┤ │ZZ(0.15) ├──────────┤┌───┐           ┌───┐»
# «qv.1: ─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────┤ H ├»
# «                 ├───┤├─────────┤           ├──────────┤├───┤ │ZZ(0.15) ├───┤»
# «qv.2: ─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────┤ H ├»
# «       │ZZ(0.15) ├───┤├─────────┤ │ZZ(0.15) ├──────────┤├───┤           ├───┤»
# «qv.3: ─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────┤ H ├»
# «                 ├───┤├─────────┤           ├──────────┤├───┤ │ZZ(0.15) ├───┤»
# «qv.4: ─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────┤ H ├»
# «       │ZZ(0.15) ├───┤├─────────┤ │ZZ(0.15) ├──────────┤├───┤           ├───┤»
# «qv.5: ─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────┤ H ├»
# «                 ├───┤├─────────┤           ├──────────┤├───┤ │ZZ(0.15) ├───┤»
# «qv.6: ─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────┤ H ├»
# «       │ZZ(0.15) ├───┤├─────────┤ │ZZ(0.15) ├──────────┤└───┘           └───┘»
# «qv.7: ─■─────────┤ H ├┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├─────────────────────»
# «                 └───┘└─────────┘           └──────────┘                     »
# «                                                        ┌───┐                »
# «qv.0: ───────────────────────────────────■──X──■────────┤ H ├────────────────»
# «      ┌─────────┐           ┌──────────┐ │  │  │ZZ(1.5) ├───┤           ┌───┐»
# «qv.1: ┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├─■──X──■────────┤ H ├─■─────────┤ H ├»
# «      ├─────────┤ │ZZ(0.15) ├──────────┤                ├───┤ │ZZ(0.15) ├───┤»
# «qv.2: ┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├─■──X──■────────┤ H ├─■─────────┤ H ├»
# «      ├─────────┤           ├──────────┤ │  │  │ZZ(1.5) ├───┤           ├───┤»
# «qv.3: ┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├─■──X──■────────┤ H ├─■─────────┤ H ├»
# «      ├─────────┤ │ZZ(0.15) ├──────────┤                ├───┤ │ZZ(0.15) ├───┤»
# «qv.4: ┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├─■──X──■────────┤ H ├─■─────────┤ H ├»
# «      ├─────────┤           ├──────────┤ │  │  │ZZ(1.5) ├───┤           ├───┤»
# «qv.5: ┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├─■──X──■────────┤ H ├─■─────────┤ H ├»
# «      ├─────────┤ │ZZ(0.15) ├──────────┤                ├───┤ │ZZ(0.15) ├───┤»
# «qv.6: ┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├─■──X──■────────┤ H ├─■─────────┤ H ├»
# «      └─────────┘           └──────────┘ │  │  │ZZ(1.5) ├───┤           └───┘»
# «qv.7: ───────────────────────────────────■──X──■────────┤ H ├────────────────»
# «                                                        └───┘                »
# «                                                        ┌───┐┌─────────┐»
# «qv.0: ────────────────────────────────────────■─────────┤ H ├┤ Rx(π/2) ├»
# «      ┌─────────┐           ┌──────────┐┌───┐ │ZZ(0.15) ├───┤├─────────┤»
# «qv.1: ┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├»
# «      ├─────────┤ │ZZ(0.15) ├──────────┤├───┤           ├───┤├─────────┤»
# «qv.2: ┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├»
# «      ├─────────┤           ├──────────┤├───┤ │ZZ(0.15) ├───┤├─────────┤»
# «qv.3: ┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├»
# «      ├─────────┤ │ZZ(0.15) ├──────────┤├───┤           ├───┤├─────────┤»
# «qv.4: ┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├»
# «      ├─────────┤           ├──────────┤├───┤ │ZZ(0.15) ├───┤├─────────┤»
# «qv.5: ┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├»
# «      ├─────────┤ │ZZ(0.15) ├──────────┤├───┤           ├───┤├─────────┤»
# «qv.6: ┤ Rx(π/2) ├─■─────────┤ Rx(-π/2) ├┤ H ├─■─────────┤ H ├┤ Rx(π/2) ├»
# «      └─────────┘           └──────────┘└───┘ │ZZ(0.15) ├───┤├─────────┤»
# «qv.7: ────────────────────────────────────────■─────────┤ H ├┤ Rx(π/2) ├»
# «                                                        └───┘└─────────┘»
# «                 ┌──────────┐┌───────┐
# «qv.0: ─■─────────┤ Rx(-π/2) ├┤ Rz(0) ├
# «       │ZZ(0.15) ├──────────┤├───────┤
# «qv.1: ─■─────────┤ Rx(-π/2) ├┤ Rz(0) ├
# «                 ├──────────┤├───────┤
# «qv.2: ─■─────────┤ Rx(-π/2) ├┤ Rz(0) ├
# «       │ZZ(0.15) ├──────────┤├───────┤
# «qv.3: ─■─────────┤ Rx(-π/2) ├┤ Rz(0) ├
# «                 ├──────────┤├───────┤
# «qv.4: ─■─────────┤ Rx(-π/2) ├┤ Rz(0) ├
# «       │ZZ(0.15) ├──────────┤├───────┤
# «qv.5: ─■─────────┤ Rx(-π/2) ├┤ Rz(0) ├
# «                 ├──────────┤├───────┤
# «qv.6: ─■─────────┤ Rx(-π/2) ├┤ Rz(0) ├
# «       │ZZ(0.15) ├──────────┤├───────┤
# «qv.7: ─■─────────┤ Rx(-π/2) ├┤ Rz(0) ├
# «                 └──────────┘└───────┘
# Live QuantumVariables:
# ----------------------
# QuantumVariable qv
# {'10011001': 0.2420648412968259, '10011010': 0.09481189623792476, '01011001': 0.09481189623792476, '10101001': 0.07875157503150063, '10010101': 0.07875157503150063, '10010110': 0.03904078081561631, '01101001': 0.03904078081561631, '01011010': 0.03716074321486429, '10100101': 0.032230644612892254, '10101010': 0.030380607612152243, '01010101': 0.030380607612152243, '10100110': 0.015960319206384126, '01100101': 0.015960319206384126, '01101010': 0.015070301406028119, '01010110': 0.015070301406028119, '10011100': 0.010910218204364086, '00111001': 0.010910218204364086, '11001001': 0.010680213604272085, '10010011': 0.010680213604272085, '10110001': 0.009560191203824077, '10001101': 0.009560191203824077, '01100110': 0.007900158003160063, '10001110': 0.004560091201824036, '01110001': 0.004560091201824036, '10110010': 0.004290085801716035, '01001101': 0.004290085801716035, '01011100': 0.004240084801696033, '00111010': 0.004240084801696033, '11000101': 0.004200084001680033, '10100011': 0.004200084001680033, '11001010': 0.004140082801656032, '01010011': 0.004140082801656032, '10101100': 0.004050081001620032, '00110101': 0.004050081001620032, '11000110': 0.0020800416008320164, '01100011': 0.0020800416008320164, '01110010': 0.0020400408008160163, '01001110': 0.0020400408008160163, '01101100': 0.0020000400008000157, '00110110': 0.0020000400008000157, '11010001': 0.0007800156003120062, '10001011': 0.0007800156003120062, '11000011': 0.0005500110002200043, '00111100': 0.0005400108002160043, '11001100': 0.0005200104002080041, '00110011': 0.0005200104002080041, '10111000': 0.0004000080001600032, '00011101': 0.0004000080001600032, '11010010': 0.0003400068001360027, '01001011': 0.0003400068001360027, '10110100': 0.0003300066001320026, '00101101': 0.0003300066001320026, '01111000': 0.00018000360007200142, '00011110': 0.00018000360007200142, '11100001': 0.00018000360007200142, '10000111': 0.00018000360007200142, '01110100': 0.0001600032000640013, '00101110': 0.0001600032000640013, '11100010': 8.000160003200064e-05, '01000111': 8.000160003200064e-05, '11010100': 3.000060001200024e-05, '00101011': 3.000060001200024e-05, '11101000': 1.000020000400008e-05, '00010111': 1.000020000400008e-05}

# %%
qt = qc.qs.to_qiskit()


circuit_drawer(qt, output="mpl")
